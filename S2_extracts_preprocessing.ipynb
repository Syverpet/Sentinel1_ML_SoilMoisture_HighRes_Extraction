# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
#[nr_' 'TRI' 'TPI' 'slope' 'elev']

# %%
# Rekkefølge
#A13, A19, A01,   B07, B13, B19, B01


#DEM dataframes
dfA = pd.read_csv("C:/Users/Laptop/Documents/1. Thesis 2021/Data/DEM/Extracted/A_DEM_values.csv")
dfB = pd.read_csv("C:/Users/Laptop/Documents/1. Thesis 2021/Data/DEM/Extracted/B_DEM_values.csv")
dfB7 = pd.read_csv("C:/Users/Laptop/Documents/1. Thesis 2021/Data/DEM/Extracted/B7_DEM_values.csv")

dfB['nr_'] = dfB['nr_']+30
dfB7['nr_'] = dfB7['nr_']+30

dfA.rename(columns={"nr_": "nr_dem"}, inplace = True)
dfB.rename(columns={"nr_": "nr_dem"}, inplace = True)
dfB7.rename(columns={"nr_": "nr_dem"}, inplace = True)


df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/A_bufferednd_V_i_13.csv")


lst_A_13 = ['A_bufferednd_I_i_13', 'A_bufferednd_W_i_13', 'A_bufferednd_V_i_13']
lst_A_19 = ['A_bufferednd_I_i_19', 'A_bufferednd_W_i_19', 'A_bufferednd_V_i_19']
lst_A_01 = ['A_bufferednd_I_i_01', 'A_bufferednd_W_i_01', 'A_bufferednd_V_i_01']

lst_B_07 = ['B_buff_7nd_I_i_07', 'B_buff_7nd_W_i_07', 'B_buff_7nd_V_i_07']
lst_B_13 = ['B_bufferednd_I_i_13', 'B_bufferednd_W_i_13', 'B_bufferednd_V_i_13']
lst_B_19 = ['B_bufferednd_I_i_19', 'B_bufferednd_W_i_19', 'B_bufferednd_V_i_19']
lst_B_01 = ['B_bufferednd_I_i_01', 'B_bufferednd_W_i_01', 'B_bufferednd_V_i_01']

lst_A_07 = ['A_buff_7nd_I_i_07', 'A_buff_7nd_W_i_07', 'A_buff_7nd_V_i_07']

#Empty df
df_add_all = pd.DataFrame(columns = ['nr_', 'lat', 'Vmean', 'Vmedian', 'Vstdev'])

#A13
list_ = lst_A_13
DEM = dfA

df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[0]}.csv")
df_merge2 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[1]}.csv")
df_merge3 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[2]}.csv")
df_merge2.drop(df_merge2.columns.difference(['Wmean', 'Wmedian', 'Wstdev']), 1, inplace=True)
df_merge3.drop(df_merge3.columns.difference(['Vmean', 'Vmedian', 'Vstdev']), 1, inplace=True)
df_merge4 = pd.merge(df_merge1, df_merge2, left_index=True, right_index=True)
df_merge5 = pd.merge(df_merge4, df_merge3, left_index=True, right_index=True)
df_merge5.drop(df_merge5.columns.difference(['Nr__New_fo', 'lat', 'Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1, inplace=True)

df_merge6 = pd.merge(df_merge5, DEM, left_index=True, right_index=True)

df_merge6.rename(columns={"Nr__New_fo": "nr_"}, inplace = True)


df_add_all = pd.concat([df_add_all, df_merge6])


#A19
list_ = lst_A_19
DEM = dfA

df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[0]}.csv")
df_merge2 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[1]}.csv")
df_merge3 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[2]}.csv")
df_merge2.drop(df_merge2.columns.difference(['Wmean', 'Wmedian', 'Wstdev']), 1, inplace=True)
df_merge3.drop(df_merge3.columns.difference(['Vmean', 'Vmedian', 'Vstdev']), 1, inplace=True)
df_merge4 = pd.merge(df_merge1, df_merge2, left_index=True, right_index=True)
df_merge5 = pd.merge(df_merge4, df_merge3, left_index=True, right_index=True)
df_merge5.drop(df_merge5.columns.difference(['Nr__New_fo', 'lat', 'Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1, inplace=True)
df_merge6 = pd.merge(df_merge5, DEM, left_index=True, right_index=True)

df_merge6.rename(columns={"Nr__New_fo": "nr_"}, inplace = True)


df_add_all = pd.concat([df_add_all, df_merge6])


#A01
list_ = lst_A_01
DEM = dfA

df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[0]}.csv")
df_merge2 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[1]}.csv")
df_merge3 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[2]}.csv")
df_merge2.drop(df_merge2.columns.difference(['Wmean', 'Wmedian', 'Wstdev']), 1, inplace=True)
df_merge3.drop(df_merge3.columns.difference(['Vmean', 'Vmedian', 'Vstdev']), 1, inplace=True)
df_merge4 = pd.merge(df_merge1, df_merge2, left_index=True, right_index=True)
df_merge5 = pd.merge(df_merge4, df_merge3, left_index=True, right_index=True)
df_merge5.drop(df_merge5.columns.difference(['Nr__New_fo', 'lat', 'Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1, inplace=True)
df_merge6 = pd.merge(df_merge5, DEM, left_index=True, right_index=True)

df_merge6.rename(columns={"Nr__New_fo": "nr_"}, inplace = True)


df_add_all = pd.concat([df_add_all, df_merge6])


#B07
list_ = lst_B_07
DEM = dfB7

df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[0]}.csv") 
df_merge2 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[1]}.csv")
df_merge3 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[2]}.csv")
df_merge2.drop(df_merge2.columns.difference(['Wmean', 'Wmedian', 'Wstdev']), 1, inplace=True)
df_merge3.drop(df_merge3.columns.difference(['Vmean', 'Vmedian', 'Vstdev']), 1, inplace=True)
df_merge4 = pd.merge(df_merge1, df_merge2, left_index=True, right_index=True)
df_merge5 = pd.merge(df_merge4, df_merge3, left_index=True, right_index=True)
df_merge5.drop(df_merge5.columns.difference(['nr_', 'lat', 'Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1, inplace=True)
df_merge5['nr_'] = df_merge5['nr_']+30
df_merge6 = pd.merge(df_merge5, DEM, left_index=True, right_index=True)


df_add_all = pd.concat([df_add_all, df_merge6])


#B13
list_ = lst_B_13
DEM = dfB

df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[0]}.csv")
df_merge2 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[1]}.csv")
df_merge3 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[2]}.csv")
df_merge2.drop(df_merge2.columns.difference(['Wmean', 'Wmedian', 'Wstdev']), 1, inplace=True)
df_merge3.drop(df_merge3.columns.difference(['Vmean', 'Vmedian', 'Vstdev']), 1, inplace=True)
df_merge4 = pd.merge(df_merge1, df_merge2, left_index=True, right_index=True)
df_merge5 = pd.merge(df_merge4, df_merge3, left_index=True, right_index=True)
df_merge5.drop(df_merge5.columns.difference(['nr__New_fo', 'lat', 'Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1, inplace=True)
df_merge5.rename(columns={"nr__New_fo": "nr_"}, inplace = True)
df_merge5['nr_'] = df_merge5['nr_']+30

df_merge6 = pd.merge(df_merge5, DEM, left_index=True, right_index=True)


df_add_all = pd.concat([df_add_all, df_merge6])


#B19
list_ = lst_B_19
DEM = dfB

df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[0]}.csv")
df_merge2 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[1]}.csv")
df_merge3 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[2]}.csv")
df_merge2.drop(df_merge2.columns.difference(['Wmean', 'Wmedian', 'Wstdev']), 1, inplace=True)
df_merge3.drop(df_merge3.columns.difference(['Vmean', 'Vmedian', 'Vstdev']), 1, inplace=True)
df_merge4 = pd.merge(df_merge1, df_merge2, left_index=True, right_index=True)
df_merge5 = pd.merge(df_merge4, df_merge3, left_index=True, right_index=True)
df_merge5.drop(df_merge5.columns.difference(['nr__New_fo', 'lat', 'Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1, inplace=True)
df_merge5.rename(columns={"nr__New_fo": "nr_"}, inplace = True)
df_merge5['nr_'] = df_merge5['nr_']+30

df_merge6 = pd.merge(df_merge5, DEM, left_index=True, right_index=True)


df_add_all = pd.concat([df_add_all, df_merge6])

#B01
list_ = lst_B_01
DEM = dfB

df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[0]}.csv")
df_merge2 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[1]}.csv")
df_merge3 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[2]}.csv")
df_merge2.drop(df_merge2.columns.difference(['Wmean', 'Wmedian', 'Wstdev']), 1, inplace=True)
df_merge3.drop(df_merge3.columns.difference(['Vmean', 'Vmedian', 'Vstdev']), 1, inplace=True)
df_merge4 = pd.merge(df_merge1, df_merge2, left_index=True, right_index=True)
df_merge5 = pd.merge(df_merge4, df_merge3, left_index=True, right_index=True)
df_merge5.drop(df_merge5.columns.difference(['nr__New_fo', 'lat', 'Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1, inplace=True)
df_merge5.rename(columns={"nr__New_fo": "nr_"}, inplace = True)
df_merge5['nr_'] = df_merge5['nr_']+30

df_merge6 = pd.merge(df_merge5, DEM, left_index=True, right_index=True)


df_add_all = pd.concat([df_add_all, df_merge6])


#A07
list_ = lst_A_07
DEM = dfA

df_merge1 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[0]}.csv")
df_merge2 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[1]}.csv")
df_merge3 = pd.read_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Sentinel2/final_csv/{list_[2]}.csv")
df_merge2.drop(df_merge2.columns.difference(['Wmean', 'Wmedian', 'Wstdev']), 1, inplace=True)
df_merge3.drop(df_merge3.columns.difference(['Vmean', 'Vmedian', 'Vstdev']), 1, inplace=True)
df_merge4 = pd.merge(df_merge1, df_merge2, left_index=True, right_index=True)
df_merge5 = pd.merge(df_merge4, df_merge3, left_index=True, right_index=True)
df_merge5.drop(df_merge5.columns.difference(['nr__New_fo', 'lat', 'Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1, inplace=True)
df_merge5.rename(columns={"Nr__New_fo": "nr_"}, inplace = True)


df_merge6 = pd.merge(df_merge5, DEM, left_index=True, right_index=True)


df_add_all = pd.concat([df_add_all, df_merge6])


df_add_all3 = df_add_all.reset_index()
df_add_all4 = df_add_all3.rename(columns={"lat": "lat_s2"})

df_add_all4
#
# Out:
# C:\Users\Laptop\anaconda3\envs\snappy\lib\site-packages\ipykernel_launcher.py:53: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\Laptop\anaconda3\envs\snappy\lib\site-packages\ipykernel_launcher.py:73: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\Laptop\anaconda3\envs\snappy\lib\site-packages\ipykernel_launcher.py:93: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# ...

# %%
# Merge with soil moisture data and export

SM_All = pd.read_csv("C:/Users/Laptop/Documents/1. Thesis 2021/Data/Soil moisture/All/Field_A_no7.csv")

SM_All2 =  pd.concat([SM_All, df_add_all4], axis=1)
    
SM_All2.to_csv(f"C:/Users/Laptop/Documents/1. Thesis 2021/Data/Soil moisture/All/Field_A_no7_with_S2.csv")

SM_All2

plotdf = SM_All2.drop(SM_All2.columns.difference(['Vmean', 'Vmedian', 'Vstdev', 'Wmean', 'Wmedian', 'Wstdev', 'Imean', 'Imedian', 'Istdev']), 1)
plotdf2 = SM_All2.drop(SM_All2.columns.difference(['TRI', 'TPI']), 1)


#plotdf.plot(style=['o','rx'])
plotdf2.plot(style=['o','rx'])

# %%
SM_All2
# Out:
#     Field  Nr        Date        lat      long  std_moisture  M mean 1-4  \
# 0       A   1  13.11.2021  38.611109 -7.294236          0.50   16.600000
# 1       A   2  13.11.2021  38.610997 -7.294442          1.45   15.700000
# 2       A   3  13.11.2021  38.610873 -7.294658          1.01   21.000000
# 3       A   4  13.11.2021  38.610758 -7.294850          0.86   21.500000
# 4       A   5  13.11.2021  38.610630 -7.295073          1.62   24.100000
# ..    ...  ..         ...        ...       ...           ...         ...
# 210     A  22  07.11.2021  38.611385 -7.294604          0.00   17.893932
# 211     A  23  07.11.2021  38.611269 -7.294797          0.00   18.002583
# 212     A  24  07.11.2021  38.611146 -7.295009          0.00   21.736519
# 213     A  25  07.11.2021  38.611039 -7.295201          0.00   27.058325
# 214     A  26  07.11.2021  38.610926 -7.295388          0.00   17.925835
#
#      index     Imean   Imedian    Istdev    TPI    TRI     Vmean   Vmedian  \
# ...
